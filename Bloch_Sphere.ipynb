# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector, plot_state_qsphere
import numpy as np
# %matplotlib inline

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

theta = (float(input("Insira o ângulo theta em graus: ")))*np.pi/(180)
phi = (float(input("Insira o ângulo phi em graus: ")))*np.pi/(180)

alpha = complex(np.cos(theta/2))
beta = complex(np.exp(1j*phi))*np.sin(theta/2)

initial_state = np.array([alpha,beta])
# Out:
# Insira o ângulo theta em graus: 120
# Insira o ângulo phi em graus: 60

# %%
qc.initialize(initial_state,qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
qc.x(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
qc.x(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.z(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.x(qubit)
qc.z(qubit)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.y(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.x(qubit)
qc.y(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.h(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.x(qubit)
qc.h(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.h(qubit)
qc.z(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.x(qubit)
qc.h(qubit)
qc.z(qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
theta = int(input('Digite o ângulo de rotação: '))
# Out:
# Digite o ângulo de rotação: 90

# %%
qc.rx(theta*np.pi/180,qubit)
#qc.ry(-np.pi/2,qubit)
#qc.rz(np.pi/2,qubit)

qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)

# %%
plot_state_qsphere(state_vector)

# %%
qubit = QuantumRegister(1, name='qubit')

qc = QuantumCircuit(qubit)

qc.draw('mpl')

# %%
qc.u3(np.pi/2,0,np.pi,qubit)
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
state_vector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(state_vector)
